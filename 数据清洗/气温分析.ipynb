# %%
from pyecharts.charts import Line
from pyecharts import options as opts
import pandas as pd
import os

# %%
df= pd.read_csv(r'D:\vscode\susu\susu\susu\数据清洗\concat_weather.csv')

# %%
df.set_index('日期',inplace=True)

# %%
# date2011= df.loc['2011年09月01日':'2011年10月31日','最高气温']
# date2012= df.loc['2012年09月01日':'2012年10月31日','最高气温']
# date2013= df.loc['2013年09月01日':'2013年10月31日','最高气温']
# date2014= df.loc['2014年09月01日':'2014年10月31日','最高气温']
# date2015= df.loc['2015年09月01日':'2015年10月31日','最高气温']
# date2016= df.loc['2016年09月01日':'2016年10月31日','最高气温']
# date2017= df.loc['2017年09月01日':'2017年10月31日','最高气温']
# date2018= df.loc['2018年09月01日':'2018年10月31日','最高气温']
# date2019= df.loc['2019年09月01日':'2019年10月31日','最高气温']
# date2020= df.loc['2020年09月01日':'2020年10月31日','最高气温']
# date2021= df.loc['2021年09月01日':'2021年10月31日','最高气温']
# date2022= df.loc['2022年09月01日':'2022年10月31日','最高气温']
def query_101(df):
    return df.index.str.find('09月')
date_0901= df.loc[query_101,'最高气温']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 15
#      13 def query_101(df):
#      14     return df.index.str.find('09月')
# ---> 15 date_0901= df.loc[query_101,'最高气温']
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1247, in _LocIndexer._getitem_tuple(self, tup)
#    1245 with suppress(IndexingError):
#    1246     tup = self._expand_ellipsis(tup)
# -> 1247     return self._getitem_lowerdim(tup)
# ...

# %%
df.index.str.extract(r'(\d{2}年)')
# Out:
#         0
# 0     11年
# 1     11年
# 2     11年
# 3     11年
# 4     11年
# ...   ...
# 4450  23年
# 4451  23年
# 4452  23年
# 4453  23年
# 4454  23年
#
# [4455 rows x 1 columns]

# %% [markdown]
#    昨天的学习之后我对DISC的模型很感兴趣，并进行了一定的资料查找与分析，总结了以下2点：
#   1、 D支配型的人通常具有强烈的自信和决断力，他们喜欢掌控局面，追求权力和成功。他们通常具有很强的领导能力和决策能力，能够在压力下保持冷静和果断。但是，他们也容易显得傲慢和专横，缺乏耐心和细节把控能力。对于我个人而言，我在某些方面也具有D支配型的特点，比如我喜欢掌控局面，追求成功和成就。但是，我也意识到自己在某些时候可能会显得过于傲慢和专横，缺乏耐心和细节把控能力。因此，我需要不断地反思和提高自己的能力，以更好地发挥自己的优势和避免劣势。
#
#   2、I影响型的人通常很善于交际和沟通，他们具有热情、乐观的性格，喜欢与人交往并影响他人。他们通常具有很强的口才和表达能力，能够很好地激励和感染他人。但是，他们也容易过于情绪化和表面化，缺乏深度思考和冷静分析能力。对于我个人而言，我在某些方面也具有I影响型的特点，比如我喜欢与人交往和沟通，能够很好地激励和感染他人。但是，我也意识到自己在某些时候可能会过于情绪化和表面化，缺乏深度思考和冷静分析能力。因此，我需要不断地提高自己的思考和分析能力，以更好地发挥自己的优势和避免劣势。
#
# 总之，D支配型和I影响型是两种比较常见的性格类型，它们都具有一定的优势和劣势。对于自己而言，我需要不断地反思和提高自己的能力，以更好地发挥自己的优势和避免劣势。同时，我也需要学会欣赏和尊重他人的不同性格特点，以更好地与人相处和合作。

# %%
# line= Line()
# line.add_xaxis(df.index.to_list())

# line.add_yaxis('2011年气温',date2011.round(2).to_list())
# line.add_yaxis('2012年气温',date2012.round(2).to_list())
# line.add_yaxis('2013年气温',date2013.round(2).to_list())
# line.add_yaxis('2014年气温',date2014.round(2).to_list())
# line.add_yaxis('2015年气温',date2015.round(2).to_list())
# line.add_yaxis('2016年气温',date2016.round(2).to_list())
# line.add_yaxis('2017年气温',date2017.round(2).to_list())
# line.add_yaxis('2018年气温',date2018.round(2).to_list())
# line.add_yaxis('2019年气温',date2019.round(2).to_list())
# line.add_yaxis('2020年气温',date2020.round(2).to_list())
# line.add_yaxis('2021年气温',date2021.round(2).to_list())
# line.add_yaxis('2022年气温',date2022.round(2).to_list())

# line.set_global_opts(
#     title_opts=opts.TitleOpts(title= '气温曲线'),
#     tooltip_opts=opts.TooltipOpts(trigger='axis',axis_pointer_type='cross')
# )

# %%
# line.render_notebook()

# %%
date_0901
# Out:
# 日期
# 2011年09月01日    30
# 2012年09月01日    35
# 2013年09月01日    28
# 2014年09月01日    32
# 2015年09月01日    32
# 2016年09月01日    26
# 2017年09月01日    29
# 2018年09月01日    32
# 2019年09月01日    26
# 2020年09月01日    35
# 2021年09月01日    35
# 2022年09月01日    28
# Name: 最高气温, dtype: int64

# %%
line= Line()
line.add_xaxis(date_0901.index.to_list())
line.add_yaxis('10月气温',date_0901.round(2).to_list())

line.set_global_opts(
    title_opts=opts.TitleOpts(title= '气温曲线'),
    tooltip_opts=opts.TooltipOpts(trigger='axis',axis_pointer_type='cross')
)

# %%
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="27ee4e126fa447479089a6935a9f56c2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_27ee4e126fa447479089a6935a9f56c2 = echarts.init(
#                     document.getElementById('27ee4e126fa447479089a6935a9f56c2'), 'white', {renderer: 'canvas'});
#                 var option_27ee4e126fa447479089a6935a9f56c2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...
